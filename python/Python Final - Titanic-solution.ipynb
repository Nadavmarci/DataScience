# %% [markdown]
# # Understanding the Titanic Survival
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/6e/St%C3%B6wer_Titanic.jpg" />
#
# Wellcome to the Titanic, the largest British ship at the time,  that sank in the North
# Atlantic Ocean in the early hours of 15 April 1912.
#
# In this notebook we will try to undestand the characteristics of the individuals that were at the Titanic, how many survived and who survived.
#
# Please download the titanic.csv file from the Google Drive into your computer and load it
# using Pandas.
#
# This dataset is a partial dataset used as the training set on Kaggle's Titanic challenge.
#
# ###  NOTE: Open this notebook in Jupiter and make a copy of it (File ->  Make a copy). Work on the copied notebook so you can use the original notebook as a reference for the expected results.
#
# I recommend you to try to repeat the same analysis we make here using R :-)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### change this to the path you downloded the file
path = "C:/Users/Thomas/Documents/BIDS/python/titanic.csv"

# %%
### user pandas to read the csv (read_csv())
### show the top rows

titanic = pd.read_csv(path)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Columns
#
# Those the descriptions of the variables in this dataset:
#
# <table>
#     <tr><th> PassengerId </th><td> type should be integers </td></tr>
#     <tr><th> Survived </th><td> Survived or Not </td></tr>
#     <tr><th> Pclass </th><td> Class of Travel </td></tr>
#     <tr><th> Name </th><td> Name of Passenger </td></tr>
#     <tr><th> Sex </th><td> Gender </td></tr>
#     <tr><th> Age </th><td> </td></tr>
#     <tr><th> SibSp </th><td> Number of Sibling/Spouse abord </td></tr>
#     <tr><th> Parch </th><td> Number of Parent/Child abord </td></tr>
#     <tr><th> Ticket </th><td> </td></tr>
#     <tr><th> Fare </th><td> </td></tr>
#     <tr><th> Cabin </th><td> </td></tr>
#     <tr><th> Embarked </th><td> The port in which a passenger has embarked. <br> C - Cherbourg, S - Southampton, Q = Queenstown </td></tr>
# </table>

# %% [markdown]
# #### Passangers and Survival
#
# First, lets check how many passangers are on the Titanic's dataset and how many of them survived?

# %%
passangers = titanic.count()[0]
survived = titanic.Survived.sum()

print("We have %d passangers but only %d of them survived (%f%%)" % (passangers, survived, (survived/passangers*100)))
# Out:
# We have 891 passangers but only 342 of them survived (38.383838%)

# %% [markdown]
# Answer: We have 891 passangers but only 342 of them survived (38.383838%)

# %% [markdown]
# #### Missing values
#
# How many missing values are in the dataset?

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Answer: The only variables having missing values are: Age (177), Cabin (687) and Emberked (2)

# %% [markdown]
# #### Gender distribution and survival
#
# How distributed the survivors by gender?

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby('Sex').agg({'Survived':['count',sum,'mean']})
# Out:
#        Survived
#           count  sum      mean
# Sex
# female      314  233  0.742038
# male        577  109  0.188908

# %% [markdown]
# Survived
#
# Sex		count	sum	mean
# female	  314	233	0.742038
# male	  577	109	0.188908

# %% [markdown]
# #### Age distribution and survival
#
# Plot the Age frequencies of the passangers. (use an histogram)

# %%
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
### As there are null values in Age, we have to drop those nulls adding the .dropna() function !
fig, ax = plt.subplots()
ax.hist(x=titanic['Age'].dropna())
plt.show()

# %%
### A more sophisticated example...
n, bins, patches = plt.hist(x=titanic['Age'].dropna(), bins='auto', color='#0504aa',alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of the Titanic Passengers')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 100.0)

# %%
### using seaborn... easier to create...
sns.distplot(titanic['Age'].dropna())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c9197826d86> in <module>
#       1 ### using seaborn... easier to create...
# ----> 2 sns.distplot(titanic['Age'].dropna())
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Create a new variable that will divide the passangers in four age categories:
#
# - Babies: 0-5
# - Children: 6-12 years old
# - Young: 13-17 years old
# - Adult: 18-59 years old
# - Older: 60+ years old
#
# How many (number and percent) survived on each age group? (We will use the mean function as the percentage)

# %%
### create the categorical variables
titanic['AgeGroup'] = '18-59'
titanic.loc[titanic['Age'].between(0,5),'AgeGroup'] = ' 0- 5'
titanic.loc[titanic['Age'].between(6,12),'AgeGroup'] = ' 6-12'
titanic.loc[titanic['Age'].between(13,17),'AgeGroup'] = '13-17'
titanic.loc[titanic['Age']>=60,'AgeGroup'] = '60+'
titanic.loc[np.isnan(titanic['Age']),'AgeGroup'] = None
#... your code
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked AgeGroup
# 0        0         A/5 21171   7.2500   NaN        S    18-59
# 1        0          PC 17599  71.2833   C85        C    18-59
# 2        0  STON/O2. 3101282   7.9250   NaN        S    18-59
# 3        0            113803  53.1000  C123        S    18-59
# 4        0            373450   8.0500   NaN        S    18-59
# ..     ...               ...      ...   ...      ...      ...
# 886      0            211536  13.0000   NaN        S    18-59
# 887      0            112053  30.0000   B42        S    18-59
# 888      2        W./C. 6607  23.4500   NaN        S     None
# 889      0            111369  30.0000  C148        C    18-59
# 890      0            370376   7.7500   NaN        Q    18-59
#
# [891 rows x 13 columns]

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby('AgeGroup').agg({'Survived':['count',sum,'mean']})
# Out:
#          Survived
#             count  sum      mean
# AgeGroup
#  0- 5          44   31  0.704545
#  6-12          25    9  0.360000
# 13-17          44   21  0.477273
# 18-59         575  222  0.386087
# 60+            26    7  0.269231

# %% [markdown]
# <code>
# Survived
#
# AgeGroup count	sum	mean
# 0-5	      44	31	0.704545
# 6-12	  25	9	0.360000
# 13-17	  44	21	0.477273
# 18-59	  752	274	0.364362
# 60+	      26	7	0.269231
# </code>

# %% [markdown]
# #### Age-Gender Survival
#
# Where there differences on survival by age group and gender?

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby(['Sex','AgeGroup']).agg(['count',sum,'mean'])['Survived']
# Out:
#                  count  sum      mean
# Sex    AgeGroup
# female  0- 5        21   16  0.761905
#         6-12        11    3  0.272727
#        13-17        23   19  0.826087
#        18-59       202  155  0.767327
#        60+           4    4  1.000000
# male    0- 5        23   15  0.652174
#         6-12        14    6  0.428571
#        13-17        21    2  0.095238
#        18-59       373   67  0.179625
#        60+          22    3  0.136364

# %% [markdown]
# <code>
# Survived
#
# Sex	  AgeGroup count	sum	mean
# female	0-5	    21	    16	0.761905
#         6-12	11	    3	0.272727
#         13-17	23	    19	0.826087
#         18-59	255	    191	0.749020
#         60+	    4	    4	1.000000
# male	0-5	    23	    15	0.652174
#         6-12	14	    6	0.428571
#         13-17	21	    2	0.095238
#         18-59	497	    83	0.167002
#         60+	    22	    3	0.136364
# </code>

# %% [markdown]
# #### Passenger Class and Survival
#
# Was there any difference in the survival among passangers by their ticket class (Pclass) ?

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby('Pclass').agg(['count',sum,'mean'])['Survived']
# Out:
#         count  sum      mean
# Pclass
# 1         216  136  0.629630
# 2         184   87  0.472826
# 3         491  119  0.242363

# %% [markdown]
# <code>
# Survived
#
# Pclass	count	sum	mean
#     1	216	    136	0.629630
#     2	184	    87	0.472826
#     3	491	    119	0.242363
# </code>

# %% [markdown]
# #### Traveling alone vs with family
#
# Who survived more, individuals that traveled alone or those who traveled with their families?

# %%
# first we have to determine who was alone and who was in family. Use the variables SibSp and Parchtitanic['TravelAlone'] = 0
titanic.loc[(titanic['SibSp'] >= 1) | (titanic['Parch'] >= 1),'TravelAlone'] = 1

## then use groupby() and agg() to get the table bellow
titanic.groupby('TravelAlone').agg(['count',sum,'mean'])['Survived']
# Out:
#              count  sum     mean
# TravelAlone
# 1.0            354  179  0.50565

# %% [markdown]
# <code>
# Survived
#
# TravelAlone	count	sum	mean
#     0	     354	179	0.505650
#     1	     537	163	0.303538
# </code>

# %% [markdown]
# #### Embarking port and survival
#
# Was there any difference in survival related to the embarking port?

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby('Embarked').agg(['count',sum,'mean'])['Survived']
# Out:
#           count  sum      mean
# Embarked
# C           168   93  0.553571
# Q            77   30  0.389610
# S           644  217  0.336957

# %% [markdown]
# <code>
# Survived
#
# Embarked  count	sum	mean
#     C	   168	93	0.553571
#     Q	    77	30	0.389610
#     S	   644	217	0.336957
# </code>

# %% [markdown]
# #### Paid fair and survival
#
# What was the fare range paid by the passangers?

# %%
#### use describe() to get the summary of the Fare variable
print(titanic['Fare'].describe())

### draw an histogram for the Fare variable. 
sns.distplot(titanic['Fare'])
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# How many individuals didn't paid for their ticket?
#
# Does this affected their survival?

# %%
### get the number of those with a Fare == 0
len(titanic[titanic['Fare']==0])
# Out:
# 15

# %%
### Create a new variable called Gratis and give 1 to passangers who didn't pay
titanic['Gratis'] = 0
titanic.loc[titanic['Fare']==0,'Gratis'] = 1

## then use groupby() and agg() to get the table bellow
titanic.groupby('Gratis').agg(['count',sum,'mean'])['Survived']
# Out:
#         count  sum      mean
# Gratis
# 0         876  341  0.389269
# 1          15    1  0.066667

# %% [markdown]
# Where there differences in fare rates among the same ticket classes?
#
# If the answer was yes, does those differences affected the survival of individuals?

# %%
byPclass = titanic.groupby('Pclass')
res = byPclass['Fare'].describe()
res
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
res['25%'][1]
# Out:
# 30.923949999999998

# %%
### We will use the data on the desctiptive table to divide the paid fare:
### Those who paid more than the 75% where considered 'Overpaid', 
### If paid less than the 25% where categorized as 'Underpaid', else 'Normal' fare
titanic['FareGroup'] = 'Normal'
titanic.loc[(titanic['Pclass'] == 1) & (titanic['Fare'] < res['25%'][1]),'FareGroup'] = 'Underpaid'
titanic.loc[(titanic['Pclass'] == 2) & (titanic['Fare'] < res['25%'][2]),'FareGroup'] = 'Underpaid'
titanic.loc[(titanic['Pclass'] == 3) & (titanic['Fare'] < res['25%'][3]),'FareGroup'] = 'Underpaid'

titanic.loc[(titanic['Pclass'] == 1) & (titanic['Fare'] > res['75%'][1]),'FareGroup'] = 'Overpaid'
titanic.loc[(titanic['Pclass'] == 2) & (titanic['Fare'] > res['75%'][2]),'FareGroup'] = 'Overpaid'
titanic.loc[(titanic['Pclass'] == 3) & (titanic['Fare'] > res['75%'][3]),'FareGroup'] = 'Overpaid'

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked AgeGroup  TravelAlone  \
# 0        0         A/5 21171   7.2500   NaN        S    18-59          1.0
# 1        0          PC 17599  71.2833   C85        C    18-59          1.0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    18-59          NaN
# 3        0            113803  53.1000  C123        S    18-59          1.0
# 4        0            373450   8.0500   NaN        S    18-59          NaN
# ..     ...               ...      ...   ...      ...      ...          ...
# 886      0            211536  13.0000   NaN        S    18-59          NaN
# 887      0            112053  30.0000   B42        S    18-59          NaN
# 888      2        W./C. 6607  23.4500   NaN        S     None          1.0
# 889      0            111369  30.0000  C148        C    18-59          NaN
# 890      0            370376   7.7500   NaN        Q    18-59          NaN
#
#      Gratis  FareGroup
# 0         0  Underpaid
# 1         0     Normal
# 2         0     Normal
# 3         0     Normal
# 4         0     Normal
# ..      ...        ...
# 886       0     Normal
# 887       0  Underpaid
# 888       0   Overpaid
# 889       0  Underpaid
# 890       0     Normal
#
# [891 rows x 16 columns]

# %% [markdown]
# Now we will check how many survived by Pclass and FareGroup:

# %%
## use groupby() and agg() to get the table bellow
titanic.groupby(['Pclass','FareGroup']).agg(['count',sum,'mean'])['Survived']
# Out:
#                   count  sum      mean
# Pclass FareGroup
# 1      Normal       109   72  0.660550
#        Overpaid      53   39  0.735849
#        Underpaid     54   25  0.462963
# 2      Normal       103   51  0.495146
#        Overpaid      39   23  0.589744
#        Underpaid     42   13  0.309524
# 3      Normal       277   68  0.245487
#        Overpaid     120   34  0.283333
#        Underpaid     94   17  0.180851

# %% [markdown]
# Survived
#
# Pclass	FareGroup count	sum	mean
#     1	Normal	   109	72	0.660550
#         Overpaid	53	39	0.735849
#         Underpaid	54	25	0.462963
#     2	Normal	   103	51	0.495146
#         Overpaid	39	23	0.589744
#         Underpaid	42	13	0.309524
#     3	Normal	   277	68	0.245487
#         Overpaid   120	34	0.283333
#         Underpaid	94	17	0.180851

# %% [markdown]
# #### The title passanger had and survival
#
# Which were the five most common titles passanger had? (Sir, Mr, Mrs, etc)?
#
# For this part we will take the 'Name' column and will split all the words in the name by the white space.
#
# Then we will join all the words and calculate the frequency of appearance of each world in descending order.
#
# We will take the five most common words (must be titles), and with them we will create a new column. Then we will procede as we did in the other analyses.

# %%
## Join all the words in the 'Name' column
words = ' '.join(titanic['Name'])
len(words)
print(words[0:100])
# Out:
# Braund, Mr. Owen Harris Cumings, Mrs. John Bradley (Florence Briggs Thayer) Heikkinen, Miss. Laina F

# %%
## the following code will delete the punctuation
import string

table = str.maketrans({key: None for key in string.punctuation})
words = words.translate(table)
print(words[0:100])
# Out:
# Braund Mr Owen Harris Cumings Mrs John Bradley Florence Briggs Thayer Heikkinen Miss Laina Futrelle

# %%
## now we will split by the white spaces the words string into a list
wordlist = words.split()
print(type(wordlist))
print(wordlist[1:10])
# Out:
# <class 'list'>
# ['Mr', 'Owen', 'Harris', 'Cumings', 'Mrs', 'John', 'Bradley', 'Florence', 'Briggs']

# %%
## We will count each unique word and show the top 20 in descending order
## There are lots of ways to this. We will generate a dictionary to make the counts

worddict = {x:wordlist.count(x) for x in wordlist}

wordunq, wordcnt = worddict.keys(), worddict.values()

print(len(worddict))
print(len(wordunq))
print(len(wordcnt))

#wordunq.tolist()

print(type(wordunq))
print(type(wordcnt))
# Out:
# 1526
# 1526
# 1526
# <class 'dict_keys'>
# <class 'dict_values'>

# %%
worddict
# Out:
# {'Braund': 2,
#  'Mr': 521,
#  'Owen': 2,
#  'Harris': 5,
#  'Cumings': 1,
#  'Mrs': 129,
#  'John': 44,
#  'Bradley': 2,
#  'Florence': 5,
#  'Briggs': 1,
#  'Thayer': 4,
#  'Heikkinen': 1,
#  'Miss': 182,
#  'Laina': 1,
#  'Futrelle': 2,
#  'Jacques': 3,
#  'Heath': 2,
#  'Lily': 2,
#  'May': 2,
#  'Peel': 1,
#  'Allen': 2,
#  'William': 64,
#  'Henry': 35,
#  'Moran': 3,
#  'James': 24,
#  'McCarthy': 1,
#  'Timothy': 2,
#  'J': 8,
#  'Palsson': 4,
#  'Master': 40,
#  'Gosta': 1,
#  'Leonard': 9,
#  'Johnson': 6,
#  'Oscar': 2,
#  'W': 2,
#  'Elisabeth': 4,
#  'Vilhelmina': 1,
#  'Berg': 1,
#  'Nasser': 2,
#  'Nicholas': 2,
#  'Adele': 2,
#  'Achem': 1,
#  'Sandstrom': 2,
#  'Marguerite': 1,
#  'Rut': 1,
#  'Bonnell': 1,
#  'Elizabeth': 15,
#  'Saundercock': 1,
#  'Andersson': 9,
#  'Anders': 3,
#  'Johan': 15,
#  'Vestrom': 1,
#  'Hulda': 1,
#  'Amanda': 1,
#  'Adolfina': 1,
#  'Hewlett': 1,
#  'Mary': 20,
#  'D': 3,
#  'Kingcome': 1,
#  'Rice': 5,
#  'Eugene': 3,
#  'Williams': 5,
#  'Charles': 23,
#  'Vander': 4,
#  'Planke': 3,
#  'Julius': 1,
#  'Emelia': 1,
#  'Maria': 11,
#  'Vandemoortele': 1,
#  'Masselmani': 1,
#  'Fatima': 1,
#  'Fynney': 1,
#  'Joseph': 16,
#  'Beesley': 1,
#  'Lawrence': 2,
#  'McGowan': 1,
#  'Anna': 17,
#  'Annie': 8,
#  'Sloper': 1,
#  'Thompson': 2,
#  'Torborg': 1,
#  'Danira': 1,
#  'Asplund': 4,
#  'Carl': 3,
#  'Selma': 1,
#  'Augusta': 5,
#  'Emilia': 2,
#  'Johansson': 4,
#  'Emir': 1,
#  'Farred': 1,
#  'Chehab': 1,
#  'Fortune': 4,
#  'Alexander': 11,
#  'ODwyer': 1,
#  'Ellen': 5,
#  'Nellie': 2,
#  'Todoroff': 1,
#  'Lalio': 2,
#  'Uruchurtu': 1,
#  'Don': 1,
#  'Manuel': 2,
#  'E': 6,
#  'Spencer': 2,
#  'Augustus': 2,
#  'Marie': 6,
#  'Eugenie': 2,
#  'Glynn': 1,
#  'Agatha': 1,
#  'Wheadon': 1,
#  'Edward': 18,
#  'H': 8,
#  'Meyer': 3,
#  'Edgar': 2,
#  'Holverson': 2,
#  'Oskar': 3,
#  'Mamee': 1,
#  'Hanna': 4,
#  'Cann': 1,
#  'Ernest': 9,
#  'NicolaYarred': 2,
#  'Jamila': 1,
#  'Ahlin': 1,
#  'Johanna': 2,
#  'Persdotter': 1,
#  'Larsson': 3,
#  'Turpin': 2,
#  'Robert': 10,
#  'Dorothy': 2,
#  'Ann': 3,
#  'Wonnacott': 1,
#  'Kraeff': 1,
#  'Theodor': 2,
#  'Laroche': 3,
#  'Simonne': 1,
#  'Anne': 5,
#  'Andree': 1,
#  'Devaney': 1,
#  'Margaret': 12,
#  'Delia': 3,
#  'Rogers': 1,
#  'Lennon': 1,
#  'Denis': 2,
#  'ODriscoll': 1,
#  'Bridget': 2,
#  'Samaan': 1,
#  'Youssef': 2,
#  'ArnoldFranchi': 2,
#  'Josef': 2,
#  'Josefine': 1,
#  'Franchi': 1,
#  'Panula': 6,
#  'Juha': 3,
#  'Niilo': 1,
#  'Nosworthy': 1,
#  'Richard': 14,
#  'Cater': 1,
#  'Harper': 4,
#  'Sleeper': 2,
#  'Myna': 1,
#  'Haxtun': 1,
#  'Faunthorpe': 1,
#  'Lizzie': 1,
#  'Wilkinson': 1,
#  'Ostby': 1,
#  'Engelhart': 1,
#  'Cornelius': 1,
#  'Woolner': 1,
#  'Hugh': 4,
#  'Rugg': 1,
#  'Emily': 4,
#  'Novel': 1,
#  'Mansouer': 1,
#  'West': 3,
#  'Constance': 2,
#  'Mirium': 1,
#  'Goodwin': 6,
#  'Frederick': 15,
#  'Sirayanian': 1,
#  'Orsen': 1,
#  'Icard': 1,
#  'Amelie': 1,
#  'Birkhardt': 2,
#  'Skoog': 6,
#  'Harald': 2,
#  'Stewart': 1,
#  'Albert': 8,
#  'A': 4,
#  'Moubarek': 2,
#  'Gerios': 1,
#  'Nye': 1,
#  'Ramell': 1,
#  'Crease': 1,
#  'Erna': 1,
#  'Alexandra': 2,
#  'Kink': 1,
#  'Vincenz': 1,
#  'Jenkin': 1,
#  'Stephen': 3,
#  'Curnow': 1,
#  'Lillian': 3,
#  'Amy': 3,
#  'Hood': 1,
#  'Ambrose': 1,
#  'Jr': 10,
#  'Chronopoulos': 1,
#  'Apostolos': 1,
#  'Bing': 1,
#  'Lee': 2,
#  'Moen': 1,
#  'Sigurd': 1,
#  'Hansen': 5,
#  'Staneff': 1,
#  'Ivan': 4,
#  'Moutal': 1,
#  'Rahamin': 1,
#  'Haim': 1,
#  'Caldwell': 2,
#  'Alden': 1,
#  'Gates': 1,
#  'Dowdell': 1,
#  'Waelens': 1,
#  'Achille': 1,
#  'Sheerlinck': 1,
#  'Jan': 1,
#  'Baptist': 1,
#  'McDermott': 1,
#  'Brigdet': 1,
#  'Carrau': 1,
#  'Francisco': 1,
#  'M': 3,
#  'Ilett': 1,
#  'Bertha': 5,
#  'Backstrom': 2,
#  'Karl': 9,
#  'Alfred': 12,
#  'Mathilda': 1,
#  'Gustafsson': 5,
#  'Ford': 5,
#  'Neal': 2,
#  'Slocovski': 1,
#  'Selman': 1,
#  'Francis': 6,
#  'Mabel': 3,
#  'Helen': 7,
#  'Celotti': 1,
#  'Francesco': 1,
#  'Christmann': 1,
#  'Emil': 4,
#  'Andreasson': 1,
#  'Paul': 1,
#  'Edvin': 3,
#  'Chaffee': 1,
#  'Herbert': 1,
#  'Fuller': 1,
#  'Dean': 2,
#  'Bertram': 4,
#  'Frank': 7,
#  'Coxon': 1,
#  'Daniel': 5,
#  'Shorney': 1,
#  'Goldschmidt': 1,
#  'George': 24,
#  'B': 1,
#  'Greenfield': 1,
#  'Doling': 2,
#  'T': 1,
#  'Ada': 5,
#  'Julia': 1,
#  'Bone': 1,
#  'Kantor': 2,
#  'Sinai': 2,
#  'Petranec': 1,
#  'Matilda': 4,
#  'Petroff': 2,
#  'Pastcho': 1,
#  'Pentcho': 1,
#  'White': 3,
#  'Frasar': 1,
#  'Gustaf': 5,
#  'Joel': 2,
#  'Vilhelm': 1,
#  'Mionoff': 1,
#  'Stoytcho': 1,
#  'Salkjelsvik': 1,
#  'Kristine': 1,
#  'Moss': 1,
#  'Rekic': 1,
#  'Tido': 1,
#  'Porter': 1,
#  'Walter': 5,
#  'Chamberlain': 1,
#  'Zabour': 2,
#  'Hileni': 1,
#  'Barton': 1,
#  'David': 7,
#  'Jussila': 3,
#  'Katriina': 1,
#  'Attalah': 2,
#  'Malake': 1,
#  'Pekoniemi': 1,
#  'Edvard': 3,
#  'Connors': 1,
#  'Patrick': 5,
#  'Baxter': 2,
#  'Quigg': 1,
#  'Edmond': 2,
#  'Ellis': 1,
#  'Hickman': 3,
#  'Stanley': 4,
#  'Moore': 1,
#  'Webber': 2,
#  'Susan': 2,
#  'Percival': 4,
#  'Wayland': 1,
#  'Elias': 6,
#  'McMahon': 1,
#  'Martin': 8,
#  'Madsen': 1,
#  'Fridtjof': 1,
#  'Arne': 2,
#  'Peter': 11,
#  'Ekstrom': 1,
#  'Drazenoic': 1,
#  'Jozef': 1,
#  'Coelho': 1,
#  'Domingos': 1,
#  'Fernandeo': 1,
#  'Robins': 1,
#  'Grace': 1,
#  'Charity': 1,
#  'Laury': 1,
#  'Weisz': 1,
#  'Leopold': 1,
#  'Mathilde': 2,
#  'Francoise': 1,
#  'Pede': 1,
#  'Sobey': 1,
#  'Samuel': 13,
#  'Hayden': 1,
#  'Emile': 1,
#  'Newsom': 1,
#  'Monypeny': 2,
#  'Osen': 1,
#  'Olaf': 1,
#  'Elon': 1,
#  'Giglio': 1,
#  'Victor': 8,
#  'Boulos': 4,
#  'Sultana': 1,
#  'Nysten': 1,
#  'Sofia': 6,
#  'Hakkarainen': 2,
#  'Pekka': 2,
#  'Pietari': 2,
#  'Elin': 1,
#  'Dolck': 1,
#  'Burke': 1,
#  'Jeremiah': 1,
#  'Andrew': 4,
#  'Edgardo': 1,
#  'Nicholls': 1,
#  'August': 5,
#  'Wennerstrom': 1,
#  'Robina': 1,
#  'Maggie': 2,
#  'Ruby': 1,
#  'Navratil': 3,
#  'Michel': 2,
#  'Louis': 2,
#  'Hoffman': 1,
#  'Byles': 1,
#  'Rev': 6,
#  'Thomas': 22,
#  'Roussel': 1,
#  'Davids': 1,
#  'Bateman': 1,
#  'Pears': 2,
#  'Edith': 6,
#  'Wearne': 1,
#  'Meo': 1,
#  'Alfonzo': 1,
#  'van': 2,
#  'Billiard': 1,
#  'Austin': 2,
#  'Blyler': 1,
#  'Olsen': 5,
#  'Ole': 1,
#  'Duane': 2,
#  'Gilnagh': 1,
#  'Katherine': 4,
#  'Katie': 3,
#  'Corn': 1,
#  'Harry': 6,
#  'Smiljanic': 1,
#  'Mile': 1,
#  'Sage': 7,
#  'Cribb': 1,
#  'Hatfield': 1,
#  'Watt': 1,
#  'Bessie': 2,
#  'Inglis': 1,
#  'Milne': 1,
#  'Bengtsson': 3,
#  'Viktor': 4,
#  'Calic': 2,
#  'Jovo': 1,
#  'Eino': 2,
#  'Viljami': 1,
#  'Goldsmith': 3,
#  'Frankie': 1,
#  'Chibnall': 1,
#  'Martha': 4,
#  'Bowerman': 2,
#  'Bernhardina': 1,
#  'Karlsson': 2,
#  'Baumann': 1,
#  'Ling': 1,
#  'Van': 4,
#  'der': 1,
#  'hoef': 1,
#  'Wyckoff': 1,
#  'Arthur': 13,
#  'Eleanor': 1,
#  'Ileen': 1,
#  'Sivola': 1,
#  'Antti': 2,
#  'Wilhelm': 3,
#  'Smith': 4,
#  'Clinch': 1,
#  'Klasen': 1,
#  'Klas': 1,
#  'Albin': 1,
#  'Lefebre': 4,
#  'Forbes': 1,
#  'Isham': 1,
#  'Hale': 1,
#  'Reginald': 3,
#  'Lionel': 1,
#  'Gladys': 2,
#  'Pernot': 1,
#  'Rene': 3,
#  'Clarence': 1,
#  'Hugo': 2,
#  'Becker': 2,
#  'F': 1,
#  'KinkHeilmann': 1,
#  'Luise': 1,
#  'Gretchen': 2,
#  'Rood': 1,
#  'Roscoe': 1,
#  'OBrien': 3,
#  'Hannah': 2,
#  'Godfrey': 2,
#  'Romaine': 1,
#  'Hallace': 1,
#  'C': 3,
#  'Rolmane': 1,
#  'Bourke': 3,
#  'Turcin': 1,
#  'Stjepan': 1,
#  'Pinsky': 1,
#  'Rosa': 2,
#  'Carbines': 1,
#  'AndersenJensen': 1,
#  'Carla': 1,
#  'Christine': 1,
#  'Nielsine': 1,
#  'Brown': 5,
#  'Tobin': 2,
#  'Lurette': 1,
#  'Elise': 1,
#  'Mernagh': 1,
#  'Siegwart': 1,
#  'Andreas': 2,
#  'Madigan': 1,
#  'Yrois': 1,
#  'Henriette': 1,
#  'Harbeck': 1,
#  'Vande': 2,
#  'Walle': 1,
#  'Nestor': 1,
#  'Cyriel': 1,
#  'Johanson': 1,
#  'Jakob': 3,
#  'Youseff': 1,
#  'Gerious': 2,
#  'Cohen': 1,
#  'Gurshon': 1,
#  'Gus': 1,
#  'Strom': 2,
#  'Telma': 1,
#  'Albimona': 1,
#  'Nassef': 1,
#  'Cassem': 1,
#  'Carr': 1,
#  'Blank': 1,
#  'Ali': 3,
#  'Ahmed': 1,
#  'Cameron': 1,
#  'Clear': 1,
#  'Perkin': 1,
#  'Givard': 1,
#  'Hans': 4,
#  'Kristensen': 1,
#  'Kiernan': 1,
#  'Philip': 2,
#  'Newell': 3,
#  'Madeleine': 3,
#  'Honkanen': 1,
#  'Eliina': 1,
#  'Jacobsohn': 2,
#  'Sidney': 4,
#  'Bazzani': 1,
#  'Albina': 1,
#  'Sunderland': 1,
#  'Bracken': 1,
#  'Green': 1,
#  'Nenkoff': 1,
#  'Christo': 1,
#  'Hoyt': 3,
#  'Maxfield': 2,
#  'Berglund': 2,
#  'Ivar': 1,
#  'Sven': 1,
#  'Mellors': 1,
#  'Lovell': 1,
#  'Hall': 3,
#  'Fahlstrom': 1,
#  'Jonas': 1,
#  'Irene': 1,
#  'Wallach': 1,
#  'Bengt': 1,
#  'Sjostedt': 1,
#  'Ernst': 5,
#  'Adolf': 2,
#  'Gertrud': 1,
#  'Leyson': 1,
#  'Norman': 4,
#  'Harknett': 1,
#  'Alice': 8,
#  'Phoebe': 1,
#  'Hold': 1,
#  'Collyer': 3,
#  'Marjorie': 2,
#  'Lottie': 1,
#  'Pengelly': 1,
#  'Hunt': 2,
#  'Thamine': 1,
#  'Murphy': 2,
#  'Kate': 7,
#  'Coleridge': 1,
#  'Maenpaa': 1,
#  'Matti': 2,
#  'Alexanteri': 1,
#  'Sleiman': 1,
#  'Minahan': 2,
#  'Dr': 7,
#  'Lindahl': 1,
#  'Agda': 1,
#  'Thorilda': 1,
#  'Viktoria': 1,
#  'Hamalainen': 2,
#  'Beckwith': 2,
#  'Carter': 6,
#  'Courtenay': 2,
#  'Reed': 1,
#  'Elna': 1,
#  'Persson': 2,
#  'Stead': 1,
#  'Lobb': 2,
#  'Rosblom': 2,
#  'Helena': 1,
#  'Wilhelmina': 1,
#  'Touma': 1,
#  'Darwis': 1,
#  'Hanne': 1,
#  'Razi': 2,
#  'Thorne': 2,
#  'Gertrude': 2,
#  'Maybelle': 1,
#  'Cherry': 1,
#  'Ward': 1,
#  'Parrish': 2,
#  'Lutie': 1,
#  'Davis': 3,
#  'Rojj': 1,
#  'Felix': 1,
#  'Taussig': 3,
#  'Harrison': 1,
#  'Reeves': 1,
#  'Ernesti': 1,
#  'Arvid': 2,
#  'Ulrik': 1,
#  'Graham': 3,
#  'Junkins': 1,
#  'Bissette': 1,
#  'Amelia': 3,
#  'Cairns': 1,
#  'Tornquist': 1,
#  'Mellinger': 2,
#  'Maidment': 1,
#  'Natsch': 1,
#  'Healy': 1,
#  'Hanora': 3,
#  'Nora': 3,
#  'Andrews': 3,
#  'Kornelia': 1,
#  'Theodosia': 1,
#  'Lindblom': 1,
#  'Charlotta': 2,
#  'Parkes': 1,
#  'Eric': 1,
#  'Abbott': 2,
#  'Stanton': 1,
#  'Olsson': 2,
#  'Nils': 5,
#  'Goransson': 1,
#  'de': 7,
#  'Pelsmaeker': 1,
#  'Alfons': 2,
#  'Dorking': 1,
#  'Stankovic': 1,
#  'Mulder': 1,
#  'Theodore': 1,
#  'Naidenoff': 1,
#  'Penko': 1,
#  'Hosono': 1,
#  'Masabumi': 1,
#  'Connolly': 1,
#  'Barber': 1,
#  'Bishop': 2,
#  'Dickinson': 2,
#  'Walton': 3,
#  'Levy': 1,
#  'Haas': 1,
#  'Aloisia': 1,
#  'Mineff': 1,
#  'Lewy': 1,
#  'Ervin': 1,
#  'G': 3,
#  'Mansour': 1,
#  'Allison': 3,
#  'Loraine': 1,
#  'Saalfeld': 1,
#  'Adolphe': 1,
#  'Helene': 2,
#  'DeLaudeniere': 1,
#  'Chaput': 1,
#  'Kelly': 4,
#  'McCoy': 2,
#  'Bernard': 1,
#  'Cahoone': 1,
#  'Keane': 2,
#  'Howard': 1,
#  'Hudson': 2,
#  'Trevor': 1,
#  'Fleming': 2,
#  'Penasco': 2,
#  'y': 5,
#  'Castellana': 2,
#  'Satode': 2,
#  'Josefa': 1,
#  'Perez': 1,
#  'Soto': 1,
#  'Vallejo': 1,
#  'Abelson': 2,
#  'Francatelli': 1,
#  'Laura': 1,
#  'Hays': 2,
#  'Bechstein': 1,
#  'Ryerson': 2,
#  'Borie': 1,
#  'Lahtinen': 1,
#  'Sylfven': 1,
#  'Hendekovic': 1,
#  'Ignjac': 1,
#  'Hart': 4,
#  'Benjamin': 4,
#  'Nilsson': 1,
#  'Helmina': 1,
#  'Josefina': 1,
#  'Miriam': 2,
#  'Sternin': 1,
#  'Moraweck': 1,
#  'Wick': 2,
#  'Natalie': 1,
#  'Spedden': 1,
#  'Frederic': 2,
#  'Oakley': 1,
#  'Margaretta': 1,
#  'Corning': 1,
#  'Stone': 2,
#  'Dennis': 1,
#  'Danoff': 1,
#  'Yoto': 1,
#  'Slayter': 1,
#  'Hilda': 1,
#  'Sylvia': 1,
#  'Mae': 1,
#  'Harbaugh': 1,
#  'Young': 1,
#  'Grice': 1,
#  'Nysveen': 1,
#  'Ball': 1,
#  'Hippach': 2,
#  'Jean': 3,
#  'Agnes': 3,
#  'Partner': 1,
#  'Austen': 1,
#  'Leo': 3,
#  'Edmondus': 1,
#  'Frauenthal': 2,
#  'Clara': 2,
#  'Heinsheimer': 1,
#  'Denkoff': 1,
#  'Mitto': 1,
#  'Clinton': 1,
#  'Burns': 1,
#  'Dahl': 1,
#  'Edwart': 1,
#  'Blackwell': 1,
#  'Weart': 1,
#  'Roger': 2,
#  'Collander': 1,
#  'Erik': 2,
#  'Sedgwick': 1,
#  'Waddington': 1,
#  'Fox': 1,
#  'Hubert': 1,
#  'Mildred': 1,
#  'Marion': 4,
#  'Elsie': 4,
#  'Davison': 1,
#  'Finck': 1,
#  'Coutts': 2,
#  'Loch': 1,
#  'Dimic': 1,
#  'Jovan': 1,
#  'Odahl': 1,
#  'WilliamsLambert': 1,
#  'Fletcher': 1,
#  'Fellows': 1,
#  'Tannous': 3,
#  'Yousif': 1,
#  'Wazli': 1,
#  'Vanden': 1,
#  'Steen': 1,
#  'Funk': 1,
#  'Clemmer': 1,
#  'McGovern': 1,
#  'Mockler': 1,
#  'Ellie': 1,
#  'del': 1,
#  'Carlo': 1,
#  'Sebastiano': 1,
#  'Barbara': 3,
#  'Catherine': 7,
#  'Asim': 1,
#  'Adola': 1,
#  'Adahl': 1,
#  'Mauritz': 2,
#  'Warren': 1,
#  'Manley': 1,
#  'Sophia': 2,
#  'Atkinson': 1,
#  'Moussa': 1,
#  'Mantoura': 1,
#  'Jermyn': 1,
#  'Aubart': 1,
#  'Mme': 1,
#  'Leontine': 1,
#  'Pauline': 1,
#  'Harder': 1,
#  'Achilles': 1,
#  'Wiklund': 1,
#  'Beavan': 1,
#  'Ringhini': 1,
#  'Sante': 1,
#  'Stina': 1,
#  'Viola': 1,
#  'Leila': 1,
#  'Saks': 1,
#  'Landergren': 1,
#  'Aurora': 1,
#  'Adelia': 1,
#  'Widener': 1,
#  'Elkins': 1,
#  'Betros': 1,
#  'Gideon': 1,
#  'Bidois': 1,
#  'Rosalie': 2,
#  'Nakid': 2,
#  'Tikkanen': 1,
#  'Juho': 2,
#  'Aline': 1,
#  'Towner': 1,
#  'Plotcharsky': 1,
#  'Vasil': 1,
#  'Davies': 3,
#  'Buss': 1,
#  'Sadlier': 1,
#  'Matthew': 1,
#  'Lehmann': 1,
#  'Jansson': 1,
#  'Olof': 3,
#  'Birger': 1,
#  'Hjalmar': 2,
#  'Elina': 1,
#  'McKane': 1,
#  'Pain': 1,
#  'Trout': 1,
#  'Jessie': 3,
#  'L': 5,
#  'Niskanen': 1,
#  'Adams': 1,
#  'Mari': 1,
#  'Aina': 1,
#  'Oreskovic': 2,
#  'Marija': 2,
#  'Gale': 1,
#  'Shadrach': 1,
#  'Widegren': 1,
#  'CarlCharles': 1,
#  'Richards': 4,
#  'Rowe': 1,
#  'Birkeland': 1,
#  'Monsen': 1,
#  'Ida': 3,
#  'Sdycoff': 1,
#  'Todor': 1,
#  'Daisy': 2,
#  'Cunningham': 1,
#  'Sundman': 1,
#  'Julian': 2,
#  'Meek': 1,
#  'Louise': 5,
#  'Rowley': 1,
#  'Drew': 1,
#  'Vivian': 1,
#  'Lulu': 1,
#  'Christian': 2,
#  'Silven': 1,
#  'Lyyli': 1,
#  'Karoliina': 1,
#  'Matthews': 1,
#  'Impe': 3,
#  'Catharina': 1,
#  'Gheorgheff': 1,
#  'Stanio': 1,
#  'Charters': 1,
#  'Zimmerman': 1,
#  'Danbom': 2,
#  'Gilbert': 2,
#  'Sigrid': 2,
#  'Brogren': 2,
#  'Wiseman': 1,
#  'Phillippe': 1,
#  'Clarke': 2,
#  'V': 1,
#  'Winfield': 1,
#  'Phillips': 2,
#  'Marshall': 2,
#  'Flynn': 3,
#  'Pickard': 1,
#  'Berk': 2,
#  'Trembisky': 1,
#  'BjornstromSteffansson': 1,
#  'Hakan': 1,
#  'Thorneycroft': 2,
#  'Louch': 1,
#  'Adelaide': 1,
#  'Slow': 1,
#  'Kallio': 1,
#  'Nikolai': 1,
#  'Erland': 1,
#  'Silvey': 2,
#  'Baird': 2,
#  'Lucile': 2,
#  'Polk': 2,
#  'Doolina': 1,
#  'Hocking': 3,
#  'Mark': 2,
#  'Kvillner': 1,
#  'Henrik': 2,
#  'Johannesson': 1,
#  'Esther': 1,
#  'Bloomfield': 1,
#  'Hampe': 1,
#  'Leon': 1,
#  'Petterson': 1,
#  'Reynaldo': 1,
#  'Ms': 1,
#  'Encarnacion': 1,
#  'JohannesenBratthammer': 1,
#  'Bernt': 1,
#  'Dodge': 1,
#  'Washington': 2,
#  'Violet': 1,
#  'Seward': 1,
#  'Kimber': 1,
#  'Baclini': 4,
#  'Peuchen': 1,
#  'Major': 2,
#  'Edwy': 2,
#  'Hagland': 2,
#  'Ingvald': 1,
#  'Olai': 1,
#  'Foreman': 1,
#  'Laventall': 1,
#  'Goldenberg': 2,
#  'Peduzzi': 1,
#  'Jalsevac': 1,
#  'Millet': 1,
#  'Kenyon': 1,
#  'R': 3,
#  'Toomey': 1,
#  'OConnor': 1,
#  'Maurice': 2,
#  'Anderson': 3,
#  'Morley': 2,
#  'Gee': 1,
#  'Milling': 1,
#  'Jacob': 3,
#  'Maisner': 1,
#  'Simon': 1,
#  'Goncalves': 1,
#  'Estanslas': 1,
#  'Campbell': 3,
#  'Smart': 1,
#  'Montgomery': 1,
#  'Scanlan': 1,
#  'Keefe': 1,
#  'Cacic': 2,
#  'Luka': 2,
#  'Worth': 1,
#  'Jerwan': 1,
#  'Amin': 2,
#  'S': 1,
#  'Marthe': 1,
#  'Thuillard': 1,
#  'Strandberg': 1,
#  'Clifford': 1,
#  'Quincy': 1,
#  'Renouf': 2,
#  'Lewis': 2,
#  'Hirvonen': 1,
#  'Hildur': 1,
#  'Harold': 2,
#  'Frost': 1,
#  'Anthony': 2,
#  'Wood': 1,
#  'Archie': 1,
#  'Rouse': 1,
#  'Turkula': 1,
#  'Hedwig': 2,
#  'Jeannie': 1,
#  'Jane': 5,
#  'Forby': 1,
#  'Kent': 1,
#  'Somerton': 1,
#  'Eden': 1,
#  'Leslie': 2,
#  'Neville': 1,
#  'Konrad': 1,
#  'Mathias': 2,
#  'Reiersen': 1,
#  'Windelov': 1,
#  'Einar': 1,
#  'Molson': 1,
#  'Markland': 1,
#  'Artagaveytia': 1,
#  'Ramon': 1,
#  'Roland': 1,
#  'Yousseff': 2,
#  'Eustis': 2,
#  'Mussey': 1,
#  'Shellard': 1,
#  'Waldo': 1,
#  'Daniels': 1,
#  'Svensson': 3,
#  'Petar': 1,
#  'Canavan': 1,
#  'OSullivan': 1,
#  'Laitinen': 1,
#  'Kristina': 1,
#  'Maioni': 1,
#  'Roberta': 1,
#  'Quick': 2,
#  'Brayton': 1,
#  'Margido': 1,
#  'Lang': 1,
#  'Fang': 1,
#  'Daly': 2,
#  'McGough': 1,
#  'Rothschild': 1,
#  'Barrett': 1,
#  'Coleff': 2,
#  'Satio': 1,
#  'Walker': 1,
#  'Lemore': 1,
#  ...}

# %%
## now we tranform the keys and values into lists and create with them a DataFrame

word_df = pd.DataFrame({'word': worddict.keys(), 'quantity': worddict.values()})
word_df.sort_values(by='quantity', ascending=False).head(20)
# Out:
#           word  quantity
# 1           Mr       521
# 12        Miss       182
# 5          Mrs       129
# 21     William        64
# 6         John        44
# 29      Master        40
# 22       Henry        35
# 261     George        24
# 24       James        24
# 62     Charles        23
# 372     Thomas        22
# 56        Mary        20
# 109     Edward        18
# 76        Anna        17
# 72      Joseph        16
# 46   Elizabeth        15
# 50       Johan        15
# 176  Frederick        15
# 154    Richard        14
# 421     Arthur        13

# %% [markdown]
# <code>
# Answer:
#     quantity	word
#  	521	        Mr
# 	182	        Miss
# 	129	        Mrs
# 	64	        William
# 	44	        John
# 	40	        Master
# </code>

# %% [markdown]
# We have shown here that the most common titles were Mr (521), Miss (182), Mrs (129) and Master (40).
#
# This totals 872 out of 891 passengers (97.9%).
#
# Now we will create a new variable with those titles and check for differences on survival among them.
#
# We can use the following function to decide if a title is present on a name:
#
# <code>
#  titanic['Name'].str.contains('Mr')
# </code>

# %%
titanic['Title'] = 'Other'
titanic.loc[titanic['Name'].str.contains('Mr'),'Title'] = 'Mr'
titanic.loc[titanic['Name'].str.contains('Miss'),'Title'] = 'Miss'
titanic.loc[titanic['Name'].str.contains('Mrs'),'Title'] = 'Mrs'
titanic.loc[titanic['Name'].str.contains('Master'),'Title'] = 'Master'

## then use groupby() and agg() to get the table bellow
titanic.groupby('Title').agg(['count',sum,'mean'])['Survived']
# Out:
#         count  sum      mean
# Title
# Master     40   23  0.575000
# Miss      180  126  0.700000
# Mr        518   82  0.158301
# Mrs       129  102  0.790698
# Other      24    9  0.375000

# %% [markdown]
# <code>
# Survived
#
# Title	count	sum	mean
# Master	  40	23	0.575000
# Miss	 180	126	0.700000
# Mr	     518	82	0.158301
# Mrs	     130	103	0.792308
# Other	  24	9	0.375000
# </code>
